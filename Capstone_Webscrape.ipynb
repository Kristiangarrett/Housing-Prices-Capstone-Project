# %%
#WEB SCRAPING ATTEMPT

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
URL = 'https://www.deptofnumbers.com/rent/tennessee/nashville/'

# %%
resp = requests.get(URL)

# %%
print(resp.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(resp.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html lang="en">
#  <head>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="tennessee average rent" name="keywords"/>
#   <meta content="Average monthly gross rent in Nashville Tennessee was $1,033 in 2017.  Median monthly gross residential rent in Nashville Tennessee was $1,030 in 2017.  2018 rent data for Nashville Tennessee will be released in September of 2019." name="description"/>
#   <title>
#    Residential Rent Statistics for Nashville Tennessee | Department of Numbers
#   </title>
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#           google_ad_client: "ca-pub-2637528452711498",
#           enable_page_level_ads: true
#      });
#   </script>
# ...

# %%
TABLES_FROM_WEBSITE = pd.read_html('https://www.deptofnumbers.com/rent/tennessee/nashville/')

# %%
TABLES_FROM_WEBSITE
# Out:
# [                        Unnamed: 0    2017 1 Year Change 3 Year Change
#  0             US Median Gross Rent  $1,012        +3.16%        +8.35%
#  1      Tennessee Median Gross Rent    $833        +3.35%        +8.18%
#  2  Nashville, TN Median Gross Rent  $1,030        +5.86%       +16.91%,
#      Date US Median Tennessee Median Nashville, TN Median Nashville, TN Average
#  0   2017    $1,012             $833               $1,030                $1,033
#  1   2016      $981             $806                 $973                  $985
#  2   2015      $959             $785                 $917                  $950
#  3   2014      $934             $770                 $881                  $894
#  4   2013      $905             $748                 $849                  $842
#  5   2012      $884             $730                 $828                  $835
#  6   2011      $871             $715                 $800                  $814
# ...

# %%
Nominal_Gross_Rent_Nashville = TABLES_FROM_WEBSITE[0]
Nominal_Gross_Rent_Nashville
# Out:
#                         Unnamed: 0    2017 1 Year Change 3 Year Change
# 0             US Median Gross Rent  $1,012        +3.16%        +8.35%
# 1      Tennessee Median Gross Rent    $833        +3.35%        +8.18%
# 2  Nashville, TN Median Gross Rent  $1,030        +5.86%       +16.91%

# %%
Nominal_Gross_Rent_History_Nashville = TABLES_FROM_WEBSITE[1]
Nominal_Gross_Rent_History_Nashville
# Out:
#     Date US Median Tennessee Median Nashville, TN Median Nashville, TN Average
# 0   2017    $1,012             $833               $1,030                $1,033
# 1   2016      $981             $806                 $973                  $985
# 2   2015      $959             $785                 $917                  $950
# 3   2014      $934             $770                 $881                  $894
# 4   2013      $905             $748                 $849                  $842
# 5   2012      $884             $730                 $828                  $835
# 6   2011      $871             $715                 $800                  $814
# 7   2010      $855             $697                 $783                  $784
# 8   2009      $842             $682                 $784                  $779
# 9   2008      $824             $660                 $756                  $765
# 10  2007      $789             $634                 $714                  $723
# ...

# %%
Nashville_Rental_Vacancy_Rate = TABLES_FROM_WEBSITE[5]
Nashville_Rental_Vacancy_Rate
# Out:
#     Date     US Tennessee Nashville, TN
# 0   2017  6.18%     6.67%         5.85%
# 1   2016  5.89%     6.68%         3.96%
# 2   2015  5.85%     7.13%         4.87%
# 3   2014  6.32%     7.24%         3.99%
# 4   2013  6.49%     7.86%         5.67%
# 5   2012  6.77%     7.89%         6.65%
# 6   2011  7.40%     8.54%         8.10%
# 7   2010  8.17%    10.33%         8.48%
# 8   2009  8.43%    10.52%        10.23%
# 9   2008  7.86%    10.30%         8.75%
# 10  2007  7.87%     9.20%         9.74%
# 11  2006  7.70%     9.61%         9.89%

# %%
Rent_Fraction_Income = TABLES_FROM_WEBSITE[6]
Rent_Fraction_Income
# Out:
#       Unnamed: 0    2017 1 Year Change 3 Year Change
# 0             US  20.13%        -0.30%        -0.76%
# 1      Tennessee  19.47%        -0.45%        -1.36%
# 2  Nashville, TN  19.33%        -0.12%        -0.75%

# %%
Rent_Fraction_Income_Nashville = TABLES_FROM_WEBSITE[7]
Rent_Fraction_Income_Nashville
# Out:
#     Date      US Tennessee Nashville, TN
# 0   2017  20.13%    19.47%        19.33%
# 1   2016  20.43%    19.92%        19.45%
# 2   2015  20.63%    19.93%        18.98%
# 3   2014  20.89%    20.83%        20.08%
# 4   2013  20.78%    20.26%        19.59%
# 5   2012  20.65%    20.48%        19.29%
# 6   2011  20.70%    20.58%        19.20%
# 7   2010  20.50%    20.17%        19.59%
# 8   2009  20.12%    19.61%        18.42%
# 9   2008  19.00%    18.16%        17.50%
# 10  2007  18.66%    17.96%        16.88%
# 11  2006  18.90%    18.25%        17.74%

# %%
Fraction_Renting_Household_Units = TABLES_FROM_WEBSITE[8]
Fraction_Renting_Household_Units
# Out:
#       Unnamed: 0    2017 1 Year Change 3 Year Change
# 0             US  36.13%        -0.75%        -0.77%
# 1      Tennessee  34.57%        -0.34%        +0.71%
# 2  Nashville, TN  34.98%        -0.44%        -0.55%
